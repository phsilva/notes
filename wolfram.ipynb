# %%
$Version
# Out:
# 12.1.1 for Mac OS X x86 (64-bit) (June 30, 2020)

# %%
Plot3D[Sin[x y], {x, -Pi, Pi}, {y, -Pi, Pi}]
# Out:
# -Graphics3D-

# %%
Integrate[x^2 + Sin[x], x]
# Out:
#  3
# x
# -- - Cos[x]
# 3
